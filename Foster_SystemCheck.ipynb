# %% [markdown]
# **this is bold text**
# # What I hope to get out of this course
# In this course, I hope to exceed my own expectations of my ability to learn coding languages. It feels intimidating, but I want to face these strong emotions with my openness and willingness to learn.
# ## Another thing that I hope to get out of this course
# I also want to take some of your confindence and ability to talk to a large group of people- clearly and directly. That is not my strong suit. I'm very reserved. Not only that I have so many ideas in my mind that I want to clearly project, but it is rough for me to get my thoughts out to others. I know this course will challenge this part of me and I'm kind of excited for that, while really scared haha.
# ### 1 Academic Goal and 1 Personal Goal
# ***Academic goal*** *Get an A+ in course*
#
# ***Personal goal*** *Practice effectivly communicating ideas to an audience*

# %% [markdown]
# x = 5

# %% [markdown]
# x

# %%
print (x)
# Out:
# 5

# %%
for i in [1,2,3,4]:
    print (i)
for i in [x]: 
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def say_hello (x):
    print("hello" + str(x))

# %%
say_hello("Irene")
# Out:
# helloIrene

# %%
def return_hello(x):
    y = "hello" + x
    return y

# %%
return_hello ("Irene")
# Out:
# 'helloIrene'

# %% [markdown]
# ![image.png](attachment:5ce472cd-2611-4f4b-b145-1f92e09c7ecf.png)![image.png](attachment:abbfbb08-e8d4-4c43-97b7-029aa95c04d0.png)
